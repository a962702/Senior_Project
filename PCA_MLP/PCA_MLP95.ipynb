# %% [markdown]
# # MLP

# %%
import pandas as pd
from sklearn import preprocessing
import numpy as np 
from keras.models import Sequential
from keras.layers import Input, Dense
import tensorflow as tf
from sklearn.model_selection import train_test_split
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
list0=['o',1,95,90,85]
d=[]
x=2
d.append("/content/drive/MyDrive/Colab Notebooks/dataset/PCA/x_train_"+str(list0[x])+".txt")
d.append("/content/drive/MyDrive/Colab Notebooks/dataset/PCA/y_train_"+str(list0[x])+".txt")
d.append("/content/drive/MyDrive/Colab Notebooks/dataset/PCA/x_test_"+str(list0[x])+".txt")
d.append("/content/drive/MyDrive/Colab Notebooks/dataset/PCA/y_test_"+str(list0[x])+".txt")

# %%
i=0
df0=np.loadtxt(d[i])
df1=np.loadtxt(d[i+1])
df2=np.loadtxt(d[i+2])
df3=np.loadtxt(d[i+3])


# merge files
X = np.concatenate((df0, df2), axis=0)
print(X.shape)

Y = np.concatenate((df1, df3), axis=0)
Y= np.reshape(Y, (Y.size,1))
print(Y.shape)
# Out:
# (294315, 33)
# (294315, 1)

# %%
input_size=X.shape[1]
model = Sequential()
InputLayer = Input( batch_input_shape=(None, X.shape[1]), name="dense_input", dtype=tf.float32, sparse=False, ragged=False)
model.add(InputLayer)
model.add(Dense(128, batch_input_shape=(None, X.shape[1] ), name="dense", dtype=tf.float32, activation="relu"))
model.add(Dense(39, name="dense_2", dtype=tf.float32, activation="softmax"))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy' , metrics=['sparse_categorical_accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               4352
#
#  dense_2 (Dense)             (None, 39)                5031
#
# =================================================================
# Total params: 9,383
# Trainable params: 9,383
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=123)
history = model.fit(X_train, Y_train, epochs=1000,batch_size=512, validation_split=0.05)
# Out:
# Epoch 1/1000
# 383/383 [==============================] - 2s 4ms/step - loss: 0.8238 - sparse_categorical_accuracy: 0.8340 - val_loss: 0.4898 - val_sparse_categorical_accuracy: 0.8781
# Epoch 2/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.4760 - sparse_categorical_accuracy: 0.8814 - val_loss: 0.4438 - val_sparse_categorical_accuracy: 0.8882
# Epoch 3/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.4446 - sparse_categorical_accuracy: 0.8857 - val_loss: 0.4239 - val_sparse_categorical_accuracy: 0.8903
# Epoch 4/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.4286 - sparse_categorical_accuracy: 0.8880 - val_loss: 0.4131 - val_sparse_categorical_accuracy: 0.8909
# Epoch 5/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.4181 - sparse_categorical_accuracy: 0.8885 - val_loss: 0.4028 - val_sparse_categorical_accuracy: 0.8937
# Epoch 6/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.4102 - sparse_categorical_accuracy: 0.8900 - val_loss: 0.3959 - val_sparse_categorical_accuracy: 0.8925
# Epoch 7/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.4042 - sparse_categorical_accuracy: 0.8908 - val_loss: 0.3922 - val_sparse_categorical_accuracy: 0.8946
# Epoch 8/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.3980 - sparse_categorical_accuracy: 0.8919 - val_loss: 0.3873 - val_sparse_categorical_accuracy: 0.8946
# Epoch 9/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.3931 - sparse_categorical_accuracy: 0.8925 - val_loss: 0.3833 - val_sparse_categorical_accuracy: 0.8954
# Epoch 10/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.3889 - sparse_categorical_accuracy: 0.8936 - val_loss: 0.3788 - val_sparse_categorical_accuracy: 0.8958
# Epoch 11/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.3844 - sparse_categorical_accuracy: 0.8942 - val_loss: 0.3760 - val_sparse_categorical_accuracy: 0.8960
# Epoch 12/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.3811 - sparse_categorical_accuracy: 0.8948 - val_loss: 0.3736 - val_sparse_categorical_accuracy: 0.8965
# Epoch 13/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.3780 - sparse_categorical_accuracy: 0.8950 - val_loss: 0.3733 - val_sparse_categorical_accuracy: 0.8994
# Epoch 14/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.3757 - sparse_categorical_accuracy: 0.8955 - val_loss: 0.3685 - val_sparse_categorical_accuracy: 0.8971
# Epoch 15/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.3723 - sparse_categorical_accuracy: 0.8958 - val_loss: 0.3682 - val_sparse_categorical_accuracy: 0.8987
# Epoch 16/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.3704 - sparse_categorical_accuracy: 0.8964 - val_loss: 0.3663 - val_sparse_categorical_accuracy: 0.8987
# Epoch 17/1000
# 374/383 [============================>.] - ETA: 0s - loss: 0.3684 - sparse_categorical_accuracy: 0.8967
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-38ebdf70420a> in <module>()
#       1 X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=123)
# ----> 2 history = model.fit(X_train, Y_train, epochs=1000,batch_size=512, validation_split=0.05)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1429               use_multiprocessing=use_multiprocessing,
#    1430               return_dict=True,
# -> 1431               _use_cached_eval_dataset=True)
#    1432           val_logs = {'val_' + name: val for name, val in val_logs.items()}
#    1433           epoch_logs.update(val_logs)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    1714             with tf.profiler.experimental.Trace('test', step_num=step, _r=1):
#    1715               callbacks.on_test_batch_begin(step)
# -> 1716               tmp_logs = self.test_function(iterator)
#    1717               if data_handler.should_sync:
#    1718                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     952       # In this case we have not created variables on the first call. So we can
#     953       # run the first trace but we should fail if variables are created.
# --> 954       results = self._stateful_fn(*args, **kwds)
#     955       if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     956         raise ValueError("Creating variables on a non-first call to a function"
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2956     return graph_function._call_flat(
# -> 2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#    2959   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1852       # No tape is watching; skip to running the function.
#    1853       return self._build_call_outputs(self._inference_function.call(
# -> 1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#    1856         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     502               inputs=args,
#     503               attrs=attrs,
# --> 504               ctx=ctx)
#     505         else:
#     506           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:

# %%
model.evaluate(X_test, Y_test)
y_pred = model.predict(X_test)
y_true = Y_test
print("y_true's shape: ", y_true.shape)
print("y_pred's shape: ", y_pred.shape)
pred = np.argmax(y_pred, axis = 1)
pred = np.reshape(pred, (len(pred), 1))
from sklearn.metrics import classification_report
print(classification_report(y_true, pred))
