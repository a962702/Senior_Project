# %% [markdown]
# # MLP

# %%
import pandas as pd
from sklearn import preprocessing
import numpy as np 
from keras.models import Sequential
from keras.layers import Input, Dense
import tensorflow as tf
from sklearn.model_selection import train_test_split
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
list0=['o',1,95,90,85]
d=[]
x=4
d.append("/content/drive/MyDrive/Colab Notebooks/dataset/PCA/x_train_"+str(list0[x])+".txt")
d.append("/content/drive/MyDrive/Colab Notebooks/dataset/PCA/y_train_"+str(list0[x])+".txt")
d.append("/content/drive/MyDrive/Colab Notebooks/dataset/PCA/x_test_"+str(list0[x])+".txt")
d.append("/content/drive/MyDrive/Colab Notebooks/dataset/PCA/y_test_"+str(list0[x])+".txt")

# %%
i=0
df0=np.loadtxt(d[i])
df1=np.loadtxt(d[i+1])
df2=np.loadtxt(d[i+2])
df3=np.loadtxt(d[i+3])


# merge files
X = np.concatenate((df0, df2), axis=0)
print(X.shape)

Y = np.concatenate((df1, df3), axis=0)
Y= np.reshape(Y, (Y.size,1))
print(Y.shape)
# Out:
# (294315, 22)
# (294315, 1)

# %%
print(df0.shape)
print(df1.shape)
print(df2.shape)
print(df3.shape)
# Out:
# (220717, 22)
# (220717,)
# (73598, 22)
# (73598,)

# %%
input_size=X.shape[1]
model = Sequential()
InputLayer = Input( batch_input_shape=(None, X.shape[1]), name="dense_input", dtype=tf.float32, sparse=False, ragged=False)
model.add(InputLayer)
model.add(Dense(128, batch_input_shape=(None, X.shape[1] ), name="dense", dtype=tf.float32, activation="relu"))
model.add(Dense(39, name="dense_2", dtype=tf.float32, activation="softmax"))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy' , metrics=['sparse_categorical_accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               2944
#
#  dense_2 (Dense)             (None, 39)                5031
#
# =================================================================
# Total params: 7,975
# Trainable params: 7,975
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=123)
history = model.fit(X_train, Y_train, epochs=1000,batch_size=512, validation_split=0.05)
# Out:
# Epoch 1/1000
# 383/383 [==============================] - 2s 3ms/step - loss: 0.8737 - sparse_categorical_accuracy: 0.8235 - val_loss: 0.5529 - val_sparse_categorical_accuracy: 0.8712
# Epoch 2/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.5368 - sparse_categorical_accuracy: 0.8739 - val_loss: 0.4943 - val_sparse_categorical_accuracy: 0.8844
# Epoch 3/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.4952 - sparse_categorical_accuracy: 0.8799 - val_loss: 0.4684 - val_sparse_categorical_accuracy: 0.8855
# Epoch 4/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.4732 - sparse_categorical_accuracy: 0.8814 - val_loss: 0.4524 - val_sparse_categorical_accuracy: 0.8871
# Epoch 5/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.4592 - sparse_categorical_accuracy: 0.8822 - val_loss: 0.4400 - val_sparse_categorical_accuracy: 0.8873
# Epoch 6/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.4474 - sparse_categorical_accuracy: 0.8837 - val_loss: 0.4300 - val_sparse_categorical_accuracy: 0.8890
# Epoch 7/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.4385 - sparse_categorical_accuracy: 0.8848 - val_loss: 0.4249 - val_sparse_categorical_accuracy: 0.8896
# Epoch 8/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.4314 - sparse_categorical_accuracy: 0.8867 - val_loss: 0.4216 - val_sparse_categorical_accuracy: 0.8903
# Epoch 9/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.4260 - sparse_categorical_accuracy: 0.8876 - val_loss: 0.4121 - val_sparse_categorical_accuracy: 0.8905
# Epoch 10/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.4210 - sparse_categorical_accuracy: 0.8881 - val_loss: 0.4081 - val_sparse_categorical_accuracy: 0.8902
# Epoch 11/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.4157 - sparse_categorical_accuracy: 0.8895 - val_loss: 0.4025 - val_sparse_categorical_accuracy: 0.8935
# Epoch 12/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.4127 - sparse_categorical_accuracy: 0.8903 - val_loss: 0.3998 - val_sparse_categorical_accuracy: 0.8928
# Epoch 13/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.4086 - sparse_categorical_accuracy: 0.8909 - val_loss: 0.3963 - val_sparse_categorical_accuracy: 0.8948
# Epoch 14/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.4057 - sparse_categorical_accuracy: 0.8914 - val_loss: 0.3938 - val_sparse_categorical_accuracy: 0.8947
# Epoch 15/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.4029 - sparse_categorical_accuracy: 0.8921 - val_loss: 0.3932 - val_sparse_categorical_accuracy: 0.8937
# Epoch 16/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.4003 - sparse_categorical_accuracy: 0.8925 - val_loss: 0.3925 - val_sparse_categorical_accuracy: 0.8938
# Epoch 17/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.3997 - sparse_categorical_accuracy: 0.8924 - val_loss: 0.3904 - val_sparse_categorical_accuracy: 0.8952
# Epoch 18/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.3960 - sparse_categorical_accuracy: 0.8930 - val_loss: 0.3870 - val_sparse_categorical_accuracy: 0.8951
# Epoch 19/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.3938 - sparse_categorical_accuracy: 0.8936 - val_loss: 0.3853 - val_sparse_categorical_accuracy: 0.8944
# Epoch 20/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.3924 - sparse_categorical_accuracy: 0.8936 - val_loss: 0.3831 - val_sparse_categorical_accuracy: 0.8945
# Epoch 21/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.3919 - sparse_categorical_accuracy: 0.8940 - val_loss: 0.3832 - val_sparse_categorical_accuracy: 0.8953
# Epoch 22/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.3892 - sparse_categorical_accuracy: 0.8941 - val_loss: 0.3841 - val_sparse_categorical_accuracy: 0.8959
# Epoch 23/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.3887 - sparse_categorical_accuracy: 0.8943 - val_loss: 0.3805 - val_sparse_categorical_accuracy: 0.8969
# Epoch 24/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.3859 - sparse_categorical_accuracy: 0.8945 - val_loss: 0.3803 - val_sparse_categorical_accuracy: 0.8969
# Epoch 25/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.3848 - sparse_categorical_accuracy: 0.8944 - val_loss: 0.3778 - val_sparse_categorical_accuracy: 0.8972
# Epoch 26/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.3847 - sparse_categorical_accuracy: 0.8948 - val_loss: 0.3755 - val_sparse_categorical_accuracy: 0.8976
# Epoch 27/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.3824 - sparse_categorical_accuracy: 0.8950 - val_loss: 0.3757 - val_sparse_categorical_accuracy: 0.8964
# Epoch 28/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.3814 - sparse_categorical_accuracy: 0.8951 - val_loss: 0.3747 - val_sparse_categorical_accuracy: 0.8973
# Epoch 29/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.3806 - sparse_categorical_accuracy: 0.8951 - val_loss: 0.3725 - val_sparse_categorical_accuracy: 0.8978
# Epoch 30/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.3790 - sparse_categorical_accuracy: 0.8951 - val_loss: 0.3726 - val_sparse_categorical_accuracy: 0.8975
# Epoch 31/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.3784 - sparse_categorical_accuracy: 0.8954 - val_loss: 0.3730 - val_sparse_categorical_accuracy: 0.8984
# Epoch 32/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.3774 - sparse_categorical_accuracy: 0.8954 - val_loss: 0.3721 - val_sparse_categorical_accuracy: 0.8977
# Epoch 33/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.3779 - sparse_categorical_accuracy: 0.8956 - val_loss: 0.3743 - val_sparse_categorical_accuracy: 0.8977
# Epoch 34/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.3759 - sparse_categorical_accuracy: 0.8960 - val_loss: 0.3708 - val_sparse_categorical_accuracy: 0.8993
# Epoch 35/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.3747 - sparse_categorical_accuracy: 0.8962 - val_loss: 0.3739 - val_sparse_categorical_accuracy: 0.8980
# Epoch 36/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.3741 - sparse_categorical_accuracy: 0.8957 - val_loss: 0.3710 - val_sparse_categorical_accuracy: 0.8976
# Epoch 37/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.3732 - sparse_categorical_accuracy: 0.8966 - val_loss: 0.3690 - val_sparse_categorical_accuracy: 0.8987
# Epoch 38/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.3723 - sparse_categorical_accuracy: 0.8965 - val_loss: 0.3689 - val_sparse_categorical_accuracy: 0.9003
# Epoch 39/1000
# 383/383 [==============================] - 1s 3ms/step - loss: 0.3717 - sparse_categorical_accuracy: 0.8966 - val_loss: 0.3716 - val_sparse_categorical_accuracy: 0.8989
# Epoch 40/1000
# 284/383 [=====================>........] - ETA: 0s - loss: 0.3689 - sparse_categorical_accuracy: 0.8968
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-38ebdf70420a> in <module>()
#       1 X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=123)
# ----> 2 history = model.fit(X_train, Y_train, epochs=1000,batch_size=512, validation_split=0.05)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2956     return graph_function._call_flat(
# -> 2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#    2959   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1852       # No tape is watching; skip to running the function.
#    1853       return self._build_call_outputs(self._inference_function.call(
# -> 1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#    1856         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     502               inputs=args,
#     503               attrs=attrs,
# --> 504               ctx=ctx)
#     505         else:
#     506           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:

# %%
model.evaluate(X_test, Y_test)
y_pred = model.predict(X_test)
y_true = Y_test
print("y_true's shape: ", y_true.shape)
print("y_pred's shape: ", y_pred.shape)
pred = np.argmax(y_pred, axis = 1)
pred = np.reshape(pred, (len(pred), 1))
from sklearn.metrics import classification_report
print(classification_report(y_true, pred))
